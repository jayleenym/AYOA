# %%
from confluent_kafka import Consumer, KafkaError

def main():
    settings = {
        'bootstrap.servers': 'localhost:9092',
        'group.id': 'mygroup',
        'client.id': 'client-1',
        'enable.auto.commit': True,
        'session.timeout.ms': 6000,
        'default.topic.config': {'auto.offset.reset': 'smallest'}
    }

    c = Consumer(settings)

    c.subscribe(['DC'])
    
    try:
        while True:
            msg = c.poll(0.1)
            if msg is None:
                continue
            elif not msg.error():
                a = msg.value().decode("utf-8")
                # binary String 을 String 으로 change 필요
                print('Received message: {0}'.format(a))
            elif msg.error().code() == KafkaError._PARTITION_EOF:
                print('End of partition reached {0}/{1}'.format(msg.topic(), msg.partition()))
            else:
                print('Error occured: {0}'.format(msg.error().str()))
    except KeyboardInterrupt:
        pass
    finally:
        c.close()

if __name__ == "__main__":
    
    main()
# Out:
# Error occured: Subscribed topic not available: DC: Broker: Unknown topic or partition
# Received message: {'code': '086520', 'date': '2021-12-27 20:39:13', 'title': '에코프로에이치엔 ㄹㅇ 뒤진 주식이냐?????????????', 'view': '39', 'recommend': '1'}
# Received message: 2021-12-28 07:42:19
# Received message: {'code': '086520', 'date': '2021-12-24 09:16:31', 'title': '와씨 에코프로hn은 진짜 반등도없냐??????????', 'view': '37', 'recommend': '0'}
# Received message: 2021-12-28 07:42:19
# Received message: {'code': '086520', 'date': '2021-12-24 08:46:41', 'title': '2차전지 관련주 어떤게 갠츈함?', 'view': '169', 'recommend': '0'}
# Received message: 2021-12-28 07:42:19
# Received message: {'code': '035720', 'date': '2021-12-28 00:50:58', 'title': '흠 내가 네이버 카카오 갈 수 있을까?', 'view': '31', 'recommend': '0'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-27 22:18:38', 'title': '전세 4천만원 마련 해드립니다', 'view': '31', 'recommend': '0'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-27 17:19:49', 'title': '20년동안 짝사랑 했던 여자애가 결혼한다.', 'view': '87', 'recommend': '2'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-27 16:29:17', 'title': '권력밀착 카카오 탈세 고발', 'view': '56', 'recommend': '2'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-27 15:00:48', 'title': '지금이 매수를 지켜볼 때', 'view': '64', 'recommend': '0'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-27 13:29:02', 'title': '내년 대비해서 포트폴리오 재조정하면', 'view': '55', 'recommend': '0'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-27 10:57:01', 'title': '카카오', 'view': '73', 'recommend': '1'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-26 13:50:48', 'title': '한국기업 주식시장의 현실 ', 'view': '150', 'recommend': '2'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035720', 'date': '2021-12-26 10:38:30', 'title': '여자들 크리스마스트리 인형 이딴거 꼭 사잖아', 'view': '70', 'recommend': '0'}
# Received message: 2021-12-28 07:42:26
# Received message: {'code': '035420', 'date': '2021-12-28 00:50:58', 'title': '흠 내가 네이버 카카오 갈 수 있을까?', 'view': '31', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-27 19:33:11', 'title': '내가 신이라면 이딴생각은 왜 하는거임?', 'view': '53', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-27 15:33:34', 'title': '네이버 세일 하는데 왜 안사냐?', 'view': '47', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-27 10:22:49', 'title': '조선 리딩방 동호회 따까리 끄나풀들 영업질 잘하네 ㅋㅋㅋ 이제 대놓고', 'view': '22', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-27 09:31:51', 'title': '네이버 사자마자 물림 ㅜ', 'view': '160', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-27 09:10:04', 'title': '연초까지 대형주 위주로 투자해라', 'view': '164', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-27 08:58:35', 'title': '난 현시점에선 삼전보단 네이버가 매력적이라고 본다', 'view': '207', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-27 00:34:38', 'title': '대체 MZ세대 << 이거 왜 쓰는거임?', 'view': '68', 'recommend': '3'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-26 13:50:48', 'title': '한국기업 주식시장의 현실 ', 'view': '150', 'recommend': '2'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-25 12:08:03', 'title': '여자들이 결혼 안해도 되는 이유', 'view': '155', 'recommend': '3'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-25 05:57:37', 'title': '난 걍 이재명찍어야겠다', 'view': '147', 'recommend': '10'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-24 19:18:39', 'title': '미리보는....내일 네이버 지식인....JPG', 'view': '71', 'recommend': '3'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-24 18:03:46', 'title': '네이버 종토방 리딩방 광고 많냐?', 'view': '17', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-24 16:22:38', 'title': '옛날 네이버가 ㅈㄴ 꿀주식이었는데', 'view': '97', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-24 14:21:02', 'title': '"화면 핥았을 뿐인데"…음식 맛볼 수 있는 TV 일본서 등장!!', 'view': '7778', 'recommend': '135'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-24 13:17:06', 'title': '네이버종토방 리딩방 동호회 끄나풀들 크리스마스 이브날에도 한탕해처먹네 ㅋ', 'view': '14', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '035420', 'date': '2021-12-24 10:32:02', 'title': '네이버종토방에 세력 리딩방 끄나풀들 존나 많네 ㅋㅋㅋㅋㅋㅋㅋㅋ', 'view': '64', 'recommend': '0'}
# Received message: 2021-12-28 07:42:28
# Received message: {'code': '036570', 'date': '2021-12-26 11:59:50', 'title': '주식 개장하면 엔씨소프트 사라(이유있음)', 'view': '69', 'recommend': '0'}
# Received message: 2021-12-28 07:42:30
# Received message: {'code': '036570', 'date': '2021-12-24 10:21:43', 'title': '엔씨소프트 풀매수해라', 'view': '78', 'recommend': '0'}
# Received message: 2021-12-28 07:42:30
# Received message: {'code': '036570', 'date': '2021-12-24 07:33:36', 'title': '한국을 주식에 비교하면 엔씨소프트 같음 ', 'view': '48', 'recommend': '0'}
# Received message: 2021-12-28 07:42:30
# Received message: {'code': '018260', 'date': '2021-12-26 15:52:35', 'title': '허경영 지지자들 야갤념글 화력지원 부탁합니다323234fgf', 'view': '216', 'recommend': '0'}
# Received message: 2021-12-28 07:42:36
# Received message: {'code': '005930', 'date': '2021-12-27 23:00:02', 'title': '야 삼성전자 1월에 최고가 얼마였지?', 'view': '67', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-27 10:55:08', 'title': '삼성전자사라', 'view': '93', 'recommend': '2'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-27 10:50:53', 'title': '주식얘기나해라 ㅆㅂㄹㄷㅇ', 'view': '118', 'recommend': '9'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 21:36:55', 'title': 'TSMC랑 삼성전자 같이 투자 하면 안됨? 5:5', 'view': '36', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 21:29:23', 'title': '삼성전자 때문에 동생이랑 싸운 썰', 'view': '179', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 16:37:05', 'title': '삼성전자 월요일에 가격 내려가나요?', 'view': '90', 'recommend': '1'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 15:30:43', 'title': '몇달전에 8만원 처음 갔는데 저번주 목요일 종가 7만 9900원 ㅋㅋㅋ', 'view': '43', 'recommend': '1'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 15:19:31', 'title': '전세계 주식은 삼성전자 1종목 밖에 없음.   삼성전자 아니면 주식이 아', 'view': '45', 'recommend': '1'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 15:04:56', 'title': '삼성전자에 장기투자중입니다. 잘했죠??? 한국주식은 삼성전자 1종목 밖에', 'view': '49', 'recommend': '3'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 14:13:14', 'title': '설거지론의 본질은 처녀가 아님 그러나 처녀론에 비슷하긴 함', 'view': '52', 'recommend': '1'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 13:50:48', 'title': '한국기업 주식시장의 현실 ', 'view': '150', 'recommend': '2'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 10:33:30', 'title': '한녀 만난 씹덕 쿠키영상떴다(feat.어머니)', 'view': '10562', 'recommend': '221'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 08:27:16', 'title': "넉달만에 '8만전자' 삼성전자…홍라희, 1.6조 블록딜 할까", 'view': '101', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-26 06:12:38', 'title': '비처녀와 결혼한 유부남 현실 ----- 한짤 요약', 'view': '373', 'recommend': '12'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-25 20:55:29', 'title': '김제동 결혼 아직 안했네?', 'view': '107', 'recommend': '1'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-25 20:13:00', 'title': '뉴스에서 삼성전자 사라고 살살 꼬시는데', 'view': '105', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 18:11:48', 'title': '개미는 왜 역사점 고점이나 단기 고점에 주식을 사는 것일까?', 'view': '63', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 17:38:26', 'title': '삼성전자주식,삼전주식 8만원 간지가 언젠데 아직도 8만 500원???', 'view': '125', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 17:23:27', 'title': '주식공부 뭐하러 하고 뭐하러 리딩방 가입하냐???', 'view': '49', 'recommend': '1'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 15:42:32', 'title': '주식 한번도 안해본사람 특징', 'view': '165', 'recommend': '2'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 15:08:39', 'title': '인천 퐁퐁남 경찰에 체포', 'view': '128', 'recommend': '8'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 12:00:15', 'title': '근데 삼성전자는 배당금 어찌받음?', 'view': '194', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 10:17:03', 'title': '쓰레기대결) 나보다 인생 망한 새끼만 한탄해라', 'view': '154', 'recommend': '2'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 09:29:53', 'title': '삼성전자는 돈있으면 무조건 사는게 맞다', 'view': '239', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 09:15:00', 'title': '삼성전자 결국 오르네 ㅋㅋㅋ', 'view': '221', 'recommend': '0'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 00:30:49', 'title': '최후의 엘리트 이회창', 'view': '162', 'recommend': '6'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '005930', 'date': '2021-12-24 00:28:52', 'title': '이대남들은 찢도 윤도 안된다. 그것만 명심해라.', 'view': '100', 'recommend': '1'}
# Received message: 2021-12-28 07:42:38
# Received message: {'code': '000660', 'date': '2021-12-26 13:50:48', 'title': '한국기업 주식시장의 현실 ', 'view': '150', 'recommend': '2'}
# Received message: 2021-12-28 07:42:39
# Received message: {'code': '004170', 'date': '2021-12-28 05:37:52', 'title': '실제후기) 이탈리아녀랑 결혼해라 진짜 ㅆㅂ 신세계다', 'view': '120', 'recommend': '3'}
# Received message: 2021-12-28 07:43:02
# Received message: {'code': '004170', 'date': '2021-12-27 11:38:39', 'title': '광주 홍어들 미쳤네 ㅋㅋㅋㅋㅋ', 'view': '75', 'recommend': '5'}
# Received message: 2021-12-28 07:43:02
# Received message: {'code': '004170', 'date': '2021-12-26 21:29:55', 'title': '갑자기 연ﾠ애 존나 마려워서 급발진함', 'view': '75', 'recommend': '1'}
# Received message: 2021-12-28 07:43:02
# Received message: {'code': '004170', 'date': '2021-12-26 16:40:18', 'title': '라섹하고  3주차인데 신세계인거........txt', 'view': '98', 'recommend': '0'}
# Received message: 2021-12-28 07:43:02
# Received message: {'code': '004170', 'date': '2021-12-26 11:57:44', 'title': '동거녀 둘 퐁퐁족에 시집보낸썰 2', 'view': '269', 'recommend': '11'}
# Received message: 2021-12-28 07:43:02
# Received message: {'code': '004170', 'date': '2021-12-24 02:56:03', 'title': '난 솔직히 스위스인들 내심 존경스러움', 'view': '72', 'recommend': '1'}
# Received message: 2021-12-28 07:43:02
# Received message: {'code': '028260', 'date': '2021-12-27 13:38:13', 'title': '이재명 주식종목 가져왔다 개념보내줘라', 'view': '106', 'recommend': '3'}
# Received message: 2021-12-28 07:43:06
# Received message: {'code': '026960', 'date': '2021-12-28 03:51:25', 'title': '나는 이상적으로는 여자가 훨씬 아름답다고생각함', 'view': '84', 'recommend': '1'}
# Received message: 2021-12-28 07:43:08
# Received message: {'code': '026960', 'date': '2021-12-26 12:32:55', 'title': '한국 여자들이 여성성을 완전히 잃어가는구나 하고 느꼈다', 'view': '102', 'recommend': '8'}
# Received message: 2021-12-28 07:43:08
# Received message: {'code': '026960', 'date': '2021-12-25 08:39:44', 'title': '하이퍼가미 좃까고 찐알파일수록 처녀찾음', 'view': '146', 'recommend': '2'}
# Received message: 2021-12-28 07:43:08
# Received message: {'code': '026960', 'date': '2021-12-24 19:32:30', 'title': '내 교회 얘기 안나오나 했다', 'view': '31', 'recommend': '0'}
# Received message: 2021-12-28 07:43:08
# Received message: {'code': '105560', 'date': '2021-12-27 13:38:13', 'title': '이재명 주식종목 가져왔다 개념보내줘라', 'view': '106', 'recommend': '3'}
# Received message: 2021-12-28 07:43:13

# %%
d.subscribe(["DC"])

# %%
# !pip install confluent_kafka

# %%
# 컨슈머 그룹이랑 오프셋 공부ㅜ 다시....... (쓰기)


#5분이 지나간 애들은 카프카에 파일로 저장되게 만들고 5분안에서 메모리상에서 사용. 컨슈머가 바로 그래서 모델링에 적용.
