# %% [markdown]
# # 김윤기 X나 멋있다!! 와!!!!

# %%
import sqlite3

import requests
from requests.compat import urlparse, urljoin
from requests.exceptions import HTTPError
from requests import Session
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import datetime
import pandas as pd
from tqdm import tqdm
import re

# %%
# %mkdir 친환경
# %mkdir 서비스업
# %mkdir 반도체
# %mkdir 유통업
# %mkdir 금융
# %mkdir 메타버스

# %%
def download(url, params={}, headers={}, method='GET', limit=3):
    try:
        session = Session()
        resp = session.request(method, url,
                               params=params if method.upper() == 'GET' else '',
                               data=params if method.upper() == 'POST' else '',
                               headers=headers)
        resp.raise_for_status()
    except HTTPError as e:
        if limit > 0 and e.response.status_code >= 500:
            print(limit)
            time.sleep(60)  # Server Error이기 때문에 delay를 두고 실행하기 위해서 사용한다.
            # 보통은 5분에 한 번꼴로 random하게 되도록 설정한다.
            download(url, params, headers, method, limit - 1)
        else:
            print('[{}] '.format(e.response.status_code) + url)
            print(e.response.reason)
            print(e.response.headers)

    return resp

# %%
tickers = {
    '친환경' : ['336260', '009830', '086520', '011930', '018000'],
    '서비스업' : ['035720', '035420', '036570', '041140', '018260'],
    '반도체' : ['005930', '000660', '011790', '014680', '000990'],
    '유통업' : ['023530', '004170', '008770', '028260', '026960'],
    '금융' : ['105560', '071050', '055550', '316140', '086790'],
    '메타버스' : ['047080', '089890', '030350', '230980', '069410'],
}
sdate = '2021-08-19'
edate = '2021-09-14'

# %%
hankyung = pd.DataFrame(columns = ['Type', 'Date', 'Title', 'Sub', 'Writer', 'Publish', 'File'])
hankyung
# Out:
# Empty DataFrame
# Columns: [Type, Date, Title, Sub, Writer, Publish, File]
# Index: []

# %%
headers = {
'Host': 'consensus.hankyung.com',
'Connection': 'keep-alive',
'Cache-Control': 'max-age=0',
'Upgrade-Insecure-Requests': '1',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
'Referer': 'http://consensus.hankyung.com/apps.analysis/analysis.list',
'Accept-Encoding': 'gzip, deflate',
'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,nl;q=0.6',
'Cookie': '__gads=ID=f5a863ed700b4520:T=1631066526:S=ALNI_Mad7WRSCfwnX8gtMztqLddH1Pj8Tw; _cc_id=d3261baa3344347b84e99257789ef9f8; panoramaId=0ea0fef749750c998e4a4b928a2f16d539385ff296a095f34b7cd45ab244bf23; panoramaId_expiry=1631671332082; cto_bundle=W5aFNF9aV0NGQTlmOU90ZUFSQkhLR3pmSVozNTAxQnNieTFEOExXcWI1cXhVVmhjRWlBTnVBSk5FU1JWaEdkYURXJTJGVm1URmg5U2x3cGVnMmJMS0VRJTJGZnhuSlJpeSUyQlZ1clR4MUJIZ3EyQjZvNm5IdkZDSDl6dWVUdFkzQkJDRnRSUVk0ViUyRkFmbVkwWTlWWEZ4ZUVUV01nOWl0QSUzRCUzRA; _ga_Y2DVPQKG52=GS1.1.1631066707.1.1.1631066783.0; gtmdlkr=; _gid=GA1.2.1755634602.1631539164; _ga=GA1.2.792891774.1628520499; _ga_SK6NCMLNS5=GS1.1.1631539163.7.1.1631539241.60'
}

# %%
for key in tickers.keys():
    for tk in tickers[key]:
        while 1:
            p = 1
            url = f"http://consensus.hankyung.com/apps.analysis/analysis.list?sdate={sdate}&edate={edate}&now_page={p}\
            &search_value=&report_type=&pagenum=20&search_text={tk}&business_code="
            html = requests.get(url, headers=headers).content
            soup = BeautifulSoup(html, 'lxml')

            # 각 페이지
            try:
                for idx in range(1, 21):
                    report = soup.find_all('tr')[idx] # Error : 마지막 페이지 or 한 페이지에 20개 미만
                    date = report.find_all('td', text = True)[0].text
                    writer = report.find_all('td', text = True)[2].text
                    publish = report.find_all('td', text = True)[3].text
                    title = report.find('td', 'text_l').strong.text
                    sub = "\n".join(map(lambda x: x.text, report.find('td', 'text_l').find_all('li')))
                    file = report.find('a', title = True).get('title')
                    link = report.find('a', title = True).get('href') 

                    hankyung.loc[len(hankyung)] = [key, date, title, sub, writer, publish, file]

                    # pdf download
                    resp = download(f"http://consensus.hankyung.com{link}", headers=headers)
                    pdf = open(f'./{key}/{file}', 'wb')
                    pdf.write(resp.content)
                    pdf.close()
                p += 1
            except Exception:
                break

# %%
hankyung
# Out:
#     Type        Date                                              Title  \
# 0    친환경  2021-09-08                        두산퓨얼셀(336260)연료전지발전부터수소생산까지
# 1    친환경  2021-09-10              한화솔루션(009830)중국(화학)-미국(태양광)의 긍정적 나비효과
# 2    친환경  2021-09-10                        한화솔루션(009830)다시금 관심이 필요한 시점
# 3    친환경  2021-09-01                     한화솔루션(009830)RES프랑스 인수로 경쟁력 강화
# 4    친환경  2021-09-01                                한화솔루션(009830)인내의 구간
# 5   서비스업  2021-09-02                     카카오(035720)카카오톡 중심의 구독서비스 확장전략
# 6   서비스업  2021-09-07                       NAVER(035420)NARRATIVE NAVER
# 7   서비스업  2021-09-02               NAVER(035420)자사 서비스 선순환 강화를 위한 구독서비스
# 8   서비스업  2021-09-09                     엔씨소프트(036570)리니지W의 성패가 방향성을 설정
# 9   서비스업  2021-09-06                        엔씨소프트(036570)끝날 때까지 끝난게 아니다
# 10  서비스업  2021-09-02                           엔씨소프트(036570)멀티플 하향도 불가피
# 11  서비스업  2021-08-27                     엔씨소프트(036570)블소2. 기대치 미달. 읍참마속
# 12   반도체  2021-09-09                          SKC(011790)오히려 보수적인 증설 계획
# 13   반도체  2021-09-03                SKC(011790)올해 3분기, 동박 생산량 1만톤 상회 전망
# 14   반도체  2021-09-02                 SKC(011790)동박 PBR 주가 순자산 ) 25 배 도달
# 15   반도체  2021-09-01                                  SKC(011790)증설의 귀재
# 16   반도체  2021-08-31                            SKC(011790)시장 루머에 강경 대응
# 17   유통업  2021-09-13  롯데쇼핑(023530)한 샘 인 수 완 료할 경 우 롯 데 유 통 BU 에 시 너지...
# 18   유통업  2021-09-09                      신세계(004170)코로나 4차 대유행 영향은 제한적
# 19   유통업  2021-09-08                      신세계(004170)코로나 4차 대유행 영향은 제한적
# 20   유통업  2021-09-01               신세계(004170)백화점과 신세계인터내셔날 약진 , 면세 효율화
# 21   유통업  2021-09-01                호텔신라(008770)영업력과 효율화 부문 업계 경쟁 우위 유지
# 22   유통업  2021-09-01                            삼성물산(028260)고개를 드는 펀더멘탈
# 23    금융  2021-08-23            KB금융(105560)PRASAC, 높은 성장률과 마진을 향유할 M&A
# 24    금융  2021-09-10                        우리금융지주(316140)민영화터널의 끝이 보인다
# 25    금융  2021-09-10                          하나금융지주(086790)금리인상엔 금리민감주
#
#                                                   Sub   Writer  Publish  \
# 0                                      연료전지발전부터수소생산까지      나승두     SK증권
# 1   빛나는 화학 포트폴리오 - 석탄가격 강세의 직접 수혜\n태양광 - 미국에서 불어오는 훈풍      노우호    메리츠증권
# 2                         한화솔루션(009830)다시금 관심이 필요한 시점      전유진   하이투자증권
# 3                                   RES프랑스 인수로 경쟁력 강화  이동욱,권준수     키움증권
# 4                          요약\n21.8월 한화솔루션 3Q21 중간 점검      노우호    메리츠증권
# 5                                 카카오톡 중심의 구독서비스 확장전략      최관순     SK증권
# 6                            히든 밸류가 너무 많은 글로벌 빅테크 기업       이승훈  IBK투자증권
# 7                             자사 서비스 선순환 강화를 위한 구독서비스      최관순     SK증권
# 8                                      블소2의 부진을 크게 인식      김학준     키움증권
# 9                                      끝날 때까지 끝난게 아니다      김동희    메리츠증권
# 10                             기대치 를 크게 하회한 블레이드 소울 2      김소혜   한화투자증권
# 11                      엔씨소프트(036570)블소. 기대치 미달. 읍참마속      성종화   이베스트증권
# 12                                     오히려 보수적인 증설 계획  이동욱,권준수     키움증권
# 13                           올해 3분기, 동박 생산량 1만톤 상회 전망  이동욱,권준수     키움증권
# 14                     PG부문 2021 년 6 ~ 7 월부터 시황 하락 전환      황규원    유안타증권
# 15                                             증설의 귀재  이동욱,권준수     키움증권
# 16                                       시장 루머에 강경 대응      노우호    메리츠증권
# 17                               롯데그룹 6 년 만 의 M&A 추 진      안지영  IBK투자증권
# 18                                 코로나 4차 대유행 영향은 제한적      박상준     키움증권
# 19                                 코로나 4차 대유행 영향은 제한적      박상준     키움증권
# 20  기존 사업 안정화 시점 , 5 년 만에 대전백화점 출점으로 중부권 공략 , 백화점 ...  안지영,황병준  IBK투자증권
# 21                   소형 다이고 비중 확대로 면세 성장률 시장 상회 지속 전망      안지영  IBK투자증권
# 22                                  전 사업부 안정적 실적기조 지속      김세련   이베스트증권
# 23  캄보디아 소액대출금융기관 PRASAC 지분 100% 인수\nPRASAC, 자산증가율...      김은갑  IBK투자증권
# 24                                      민영화터널의 끝이 보인다      박혜진     대신증권
# 25                                        금리인상엔 금리민감주      박혜진     대신증권
#
#                      File
# 0     SK20210908두산퓨얼셀.pdf
# 1    메리츠20210910한화솔루션.pdf
# 2     하이20210910한화솔루션.pdf
# 3        키움20210901화학.pdf
# 4    메리츠20210901한화솔루션.pdf
# 5       SK20210902카카오.pdf
# 6    IBK20210907NAVER.pdf
# 7     SK20210902NAVER.pdf
# 8        키움20210909게임.pdf
# 9    메리츠20210906엔씨소프트.pdf
# 10    한화20210902엔씨소프트.pdf
# 11  이베스트20210827엔씨소프트.pdf
# 12      키움20210909SKC.pdf
# 13      키움20210903SKC.pdf
# 14     유안타20210902SKC.pdf
# 15       키움20210901화학.pdf
# 16     메리츠20210831SKC.pdf
# 17    IBK20210913롯데쇼핑.pdf
# 18      키움20210909신세계.pdf
# 19      키움20210908신세계.pdf
# 20      IBK20210901유통.pdf
# 21      IBK20210901유통.pdf
# 22   이베스트20210901삼성물산.pdf
# 23    IBK20210823KB금융.pdf
# 24   대신20210910우리금융지주.pdf
# 25   대신20210910하나금융지주.pdf
