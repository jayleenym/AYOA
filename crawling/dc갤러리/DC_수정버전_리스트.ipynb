# %%
import requests
from urllib import request
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
acode={"호텔신라":"008770","두산퓨얼셀":"336260","한화솔루션":"009830",
      "에코프로":"086520","신성이엔지":"011930","유니슨":"018000",
      "카카오":"035720","네이버":"035420","엔씨소프트":"036570",
      "sds":"018260","삼성전자":"005930","SK하이닉스":"000660",
      "skc":"011790","한솔케미칼":"014680","DB하이텍":"000990",
      "롯데쇼핑":"023530","신세계":"004170","삼성물산":"028260",
      "동서":"026960","kb금융":"105560","한국금융지주":"071050","신한지주":"055550",
      "우리금융지주":"316140","하나금융지주":"086790"}

# %%
def title_craw(ls, ticker):

    for i in range(0,len(ls)-1):
        response = requests.get('https://gall.dcinside.com' + str(ls[i]),headers=headers)
        soup = BeautifulSoup(response.content,'html.parser')
        items = soup.find_all("table",{'class':'gall_list'})
        contents = soup.find('tbody').find_all('tr')
      
        for j in contents:         
            if j.find('td',{'class':'gall_writer ub-writer'}).text=='운영자':
                pass
            else:
                #제목
                title = j.find('a').text
                #날짜
                date_tag = j.find('td',{'class':'gall_date'})
                date_dict = date_tag.attrs

                if date_dict['title'][:10] <= date_stop: return -1
                else:
                    #추천수
                    recommend_tag = j.find('td', class_='gall_recommend')

                    #조회수
                    views_tag = j.find('td', class_='gall_count')
                    views = views_tag.text
                    # View.append(views)

                    put_data = {
                        'code': ACODE[ticker],
                        'title' : title,
                        'date' : date_dict['title'],
                        'view' : views,
                        'recommend' : recommend_tag.text
                    }

                    # Mongodb에 넣는 코드
                    MongoDB.DC_title_crawl.insert_one(put_data)

# %%
page=40
BASE_URL = f"https://gall.dcinside.com/board/lists?id=neostock&s_type=search_subject_memo&s_keyword={ticker}"
ARTICLE_BASE_URL = "https://gall.dcinside.com"

a = f'/board/lists?id=neostock&s_type=search_subject_memo&s_keyword={ticker}'
# 헤더 설정
headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36'}
response = requests.get(BASE_URL,headers=headers)
soup = BeautifulSoup(response.text,'html.parser')
items = soup.find('div',{'class':"bottom_paging_box"})


#리스트 만들기 url
url_list=[a]
for i in items.find_all('a'):
    url_url = i['href']

    url_list.append(url_url)

#멈출 날짜
date_stop = '2021-09-20' 

#처음 
Title=[]
Date=[]
Rec=[]
View=[]

# %%
if __name__ == "__main__" :
    
    # 첫페이지
    title_craw(url_list)
    
    k = 0
    while k< page :
        response = requests.get('https://gall.dcinside.com' + str(url_list[-1]),headers=headers)
        soup = BeautifulSoup(response.content,'html.parser')
        items = soup.find('div',{'class':"bottom_paging_box"})
        url_list=[str(url_list[-1])]

        for i in items.find_all('a'):
            url_url = i['href']
            url_list.append(url_url)
        url_list.pop(1) 
        
        if title_craw(url_list)==-1:
            break
        else:
            k=k+1

# %%
Title
# Out:
# ['삼전 노조, 연봉 51% 인상 요구',
#  '근데 삼성전자는 지금 주워도 괜찮을 거 같은데',
#  '돈깡 수준 객관적인 평가',
#  '1월1일 비트코인 3천5백, 삼성전지 8만 3천',
#  '아직 하락 시작도 안했는데 벌써부터 죽는소리?',
#  '삼성전자 6만8천원 깨지면 무조건 튀어라 ',
#  '삼성전자보다 높은 이익률',
#  '주갤럼들 앞으로 위메이드 물렸다고 난리칠 차례임',
#  '주린이 질문있어요',
#  '삼성전자 7만원이 바닥인거같은데',
#  '내일 7만정도면 삼성전자 살만해융?(주린)',
#  '삼성전자 당분간 안오르면 좋겠다',
#  '삼성전자 올해 10만원 가는이유',
#  '줍줍하자',
#  '주식한이후로 삼성전자 안사서 다행이다',
#  '처벌받아야할 애널리스트 두명',
#  '??? 삼성전자 10만원 이라고요?',
#  '삼성전자 차트',
#  '슈퍼개미 유튜버 삼성전자 13만원 썸네일 바꿨누ㅋㅋㅋ',
#  '삼성전자 59900 얘걔리 쨰~~~~~~얚 ㅋㅋㅋㅋㅋㅋㅋ',
#  '??? 여긴 삼성전자 줄입니다',
#  '연기금: 오늘 딴놈들은 다 포기해도 삼성전자만큼은 지킨다',
#  '근데 애플이 코스피 전체시총보다 600조 많다며',
#  "이러면 삼성전자가 떡상해야 하는 거 아니냐? 'ㅅ'?",
#  '남자는 철강. 게이는 삼성전자. 네이버. 조선족은 카카오 ㅋㅋㅋㅋㅋㅋㅋ',
#  '지금 장외가로 좀 던질까? 좀 더 분석해볼까?',
#  '남자는 철강 게이는 삼성전자나 네이버 카카오 이런거 사셈 ㅋㅋㅋㅋㅋ',
#  '남자의 주식 철강. 내일부터 개떡상한다 ㄹㅇㅋㅋ',
#  '이론상으로 장투는 공매도 때문에 불가능함',
#  "삼성전자, 3분기 매출 73.1조 '사상 최대' 기록",
#  '이재명 재산 뭐냐 이거',
#  '삼성전자 주주타운.jpg',
#  '삼전 10만전자 외치던 언론.. 보도내용이 잘못은 아니라고 함.',
#  '헐~ 올해 주식투자자의 90%가 손실이란다. 뭐냐?',
#  '삼성전자 최고매출 기록 예정',
#  '걍 매수버튼 눌러놓고 기다리면 주식 년차 쌓이냐?',
#  '삼성전자 주식 보유자 평단 평균내면 7만원 위아래 어디?',
#  '근데 삼성전자우 <- 이게 무조건좋은거잖아',
#  '삼성전자 병신새끼 개잡주 ㅇㅈ?',
#  '삼전 개 쳐 물린 분들 참고',
#  '삼성전자  3% 급등 ㅗㅜㅑ',
#  '와 삼성전자 폭등 뭐노 ㄷㄷ',
#  '코스피 오늘 3300 가는거냐..?? 와 미쳤네',
#  '지금은 삼성전자의 시대',
#  '존리식 매매법 설명...',
#  '삼성전자 700억 계좌인증',
#  '삼성전자 차트로 해부하기',
#  '정보) 삼성전자 7만원대 무너지면 풀매수때려라',
#  '형들 생각 좀 알려줘 15%이윤 보자고 신경쓰는게 맞나?',
#  '유부남들 유일한 희망은 자식농사 대박내는거임',
#  '삼성전자 13만 간다는 유튜버들 왜 지금 다 아닥하고있음?',
#  '주식이 대락장이 된다는것은,',
#  'qqq, qld라는 쉬운길을 왜 다들 모를까?',
#  '삼성전자우 72층인데 왜 삼전이 72층 갈거같냐',
#  '북한과 통일하면 좋은점 1가지',
#  '삼성전자는 약세장에서 얼마나 떨어질까?',
#  '삼성전자는 주가 계산해보면 9만원은 갈 거 같은데',
#  '삼성전자 냉정하게 얘기해요',
#  '대형 우량주들 2주 후 주가 알려준다.real',
#  '응팔에서 뉴스에 코스피 1000돌파했다면서',
#  '근데 진심 삼성전자보다 이더리움이 더 잘갈거같긴함',
#  '한국비엔씨 그냥 한달사이에 제 자리 돌아온게 뭔 문제냐?',
#  '개인도 공매도 가능하잖아 담주 공매도전사모집함',
#  '삼성전자는 안망한다며 ㅡㅡ',
#  '지금 드갈만한 대형주 뭐있음?',
#  '시발 자꾸 친구가 종목추천해 달라해서',
#  '삼성전자 8.4층 살려주세요',
#  '문재앙이 애증의 관계인 이유',
#  '삼성전자 8만 4천에 물렸는데 너무너무 힘들다 진짜 너무 힘들어',
#  '삼성전자 망했냐? 왜 질질 흐름?',
#  '삼성전자 7만원에 혓바닥 낼름',
#  '코스피 4000가니까 걱정하지마! 염블리님이 말씀하심~',
#  '여자친구랑 5월달에 헤어지고 딴데 마음돌리려고 주식',
#  '삼성전자 -10%인데 백신 맞아도 되냐?',
#  '여친 때문에 주식 망했다 시발ㅋㅋ',
#  '하 진짜 주식 리얼 좆같네',
#  '추천주간다.',
#  '삼성전자 차트 봐 ㅠㅠㅠㅠㅠ',
#  '내 꿈이 삼성전자 주주 되는 거였어',
#  '안녕 형들 오늘 주식 처음 사봤어',
#  '더 좆된이유',
#  '삼성전자 주식 환불',
#  '삼성전자 5만원에 아가리 쩌억',
#  '국장 왜 떨어지냐니 ㅋㅋ 양심 있는거냐',
#  '이런 미모의 여자는 주식으로 치면 뭐냐',
#  '삼성전자 모든 음봉에 매수하라',
#  '이란,한국가전 수입 금지령',
#  '삼성전자는 나스닥 상장 못해?',
#  '삼성전자 살때가된거같다',
#  '삼성전자 무조건 6만원대는 찍는다',
#  '주갤러 계좌 평균',
#  '초심자의 행운도 이제 끝난건가 ',
#  '오늘자 삼성전자 요약.jpg',
#  '삼성전자 9만원 언제오냐',
#  '행님덜~~~',
#  '근데 삼성전자 물린건 액면분할 영향도 있음?',
#  '김민근, 삼성전자 8만원까지 반등할 것으로 예상...',
#  "USAF ' 삼성전자 5만원까지 하락한다.'",
#  '삼성전자 한달전 72,500원 까지 찍었는데 왜 74,000원이라고 사노',
#  '삼성전자 엘지전자 매수이유',
#  '하이닉스 주주만 싱글벙글',
#  '하이닉스 대박뉴스',
#  '삼성전자는 근본없는 개잡주',
#  '<속보>삼성전자 75000원 복귀',
#  '삼성전자 죽고 상신전자가 뜨네',
#  '하닉이랑 삼성전자 만났으면 좋겠다',
#  '아니 삼성전자 왜 떨어지는거냐',
#  '삼성전자 74가면 풀매수하겠단 새끼들 다 어디감??',
#  '삼성전자 75층 반등 성공 ㅋㅋ',
#  '???: 현대차와 삼성전자에 베팅하세요.',
#  '오늘 씹물장이네 ㅋㅋㅋㅋㅋㅋㅋㅋ 삼성전자보소 ㅋㅋ',
#  '삼성전자는 비싸게 왜 사는거냐',
#  '개좆됐다 삼성전자 쌍둥이형님 미국 본장에서 -3%처맞고 폐장후-4%처맞음',
#  '삼성전자 하이닉스 산애들 어카냐 ...',
#  '요즘 반도체 공급보다 수요가 더 많다며',
#  '삼성전자 목표가 100원 제시',
#  '센징이들이 이미지센서로 소니 뒤따라온다는거 팩트체크.jpg',
#  '올해 소뱅이 삼성전자 목아지딴거 모르는애들이많구나ㅋ',
#  '주갤 백수새끼들 천지인가 일본소재없으면 한국공장이 멈춘다 ㅋㅋ',
#  '내일 삼성전자 배당락일이라 팔아야 함?',
#  '삼성전자 x500배 옵션은없냐??',
#  '순이익 500억인 회사 오너vs삼성전자 대표이사 ',
#  '삼성전자 오늘 8만가는날이냐 ?',
#  '삼성전자 시외 1000원 상승 뭐노?',
#  '내일 삼성전자 2억치 살건데 몇달뒤에 인증할게',
#  '평생모은 2억 전부 삼성전자사면 되지?',
#  '2억가지고 주식할건데',
#  '한국비엔씨 vs 삼성전자',
#  '삼전3분기실적 추정치 리포트',
#  '미국이 삼성전자 기밀 내놓으라고 했던데 노아메리카 운동 언제함',
#  '29일 삼성전자 예상',
#  '꿈에서 20대 초반에 만나던 여친이랑 데이트함',
#  '삼성전자-주간 외인 매수세 증가',
#  '뉴파워 달달하노',
#  '삼성전자나 100주 산다?',
#  '증시가 조만간 폭락하는 이유를 알았다.',
#  '골드만은 왜 삼전 계속 매수하냐?',
#  '근데 삼성전자는 언젠가 10만원 찍는다는건 맞는말임?',
#  '삼성전자는 왜캐 안오름? ',
#  '삼성전자, LG 전자가 온다',
#  '골드만섹스 이새끼들 삼성전자 뭐냐',
#  '삼성전자가 테슬라 자율주행칩 만든다는데',
#  '반도체/it관련주 매수신호',
#  '삼성전자우 72000 벽 왜케 두껍냐',
#  '삼성전자 다니기 vs 게임 쌀먹 월 약 2000',
#  '이나라 강성노조 뿌리뽑을려고',
#  '[라방] 삼성전자, 테슬라의 명운을 쥐는 자율주행칩 만든다!',
#  '삼성전자가 테슬라 자율주행칩 만든다는데',
#  '형님들 저 1억 모았는데 뭐 사면 됩니까?',
#  '삼성전자 테슬라 얼마나 호재임?',
#  '삼성전자 노조의 요구사항.jpg',
#  '삼전 테슬라 관련인데도 어째 시외 반응이 1도없냐?',
#  '내일부터 인버스 개싸대기처맞는 시나리오가 완성됐네',
#  '삼성전자 내일 주가 특징과 매수 타이밍',
#  '삼성전자 대호재 떴네 ㅎㄷㄷ',
#  '배당락 다음날 삼성전자 장례식 예정',
#  '삼성전자 1000만원 이상 보유하고 있는놈 있냐 ',
#  '삼성전자 장투하는 바퀴벌레 새끼들은 왜 사냐',
#  '목표 수익률 낮거나 안정적인 투자를 원하면 미장을 해야지',
#  'ㅈ만한 시드로 산 주식 평가좀',
#  '삼성전자 의 내일( 9. 24) 주가는  하락 할 것으로 예상됩니다',
#  '우리나라 주식은 장투하지말라고',
#  '본인 장투종목 어땜?',
#  '왜 삼성전자는 계속 100원 +- 거리냐',
#  '삼성전자 다시 오르냐?',
#  '삼성전자 파멸적 상승 !!!!!!!!!!',
#  '삼성전자 뭔데 저리갭상승하냐?',
#  '삼성전자 그냥 노조 성과금 다주고 한국회사 문닫으면 안됨??',
#  '삼성전자 지금 사놓고 30년 놔두면 얼마 되냐',
#  '고2 씨드 3000만원 운용계획',
#  '목요일 삼성전자  -7% 경험하게 될것',
#  '삼성전자 애플 샤오미, 하반기 글로벌 스마트폰 시장 총공세 예고',
#  '목요일 주식 등락 종목 알려줌',
#  '350조를 개좆으로 아네',
#  '차량 반도체 공급부족 삼성전자 오르냐?',
#  '코인, 주식하는 한국인새기들이 미개하다고 느낄때 ',
#  '삼성전자 망하면 우리 나라 망해요 체고의 주식ㅠㅠ',
#  '삼성전자는 절대로 안망할회사라고 생각하고 미래가 유망하다 생각한다',
#  '코인,주식 하는 김치들이 진짜로 노답이라고 느낄때',
#  '삼성전자 진짜 대단한거 같다',
#  '헝다사태 더 알기쉽게 설명해주면(한국이 얼마나 좆됐냐하면)']

# %%
Date
# Out:
# ['2021-10-05 19:36:15',
#  '2021-10-05 18:58:28',
#  '2021-10-05 17:45:51',
#  '2021-10-05 17:37:50',
#  '2021-10-05 16:15:05',
#  '2021-10-05 16:13:54',
#  '2021-10-05 15:59:23',
#  '2021-10-05 15:43:37',
#  '2021-10-05 14:35:53',
#  '2021-10-05 13:58:22',
#  '2021-10-05 13:46:40',
#  '2021-10-05 13:31:01',
#  '2021-10-05 13:12:19',
#  '2021-10-05 11:21:22',
#  '2021-10-05 10:58:34',
#  '2021-10-05 10:32:32',
#  '2021-10-05 10:27:28',
#  '2021-10-05 10:23:02',
#  '2021-10-05 10:21:19',
#  '2021-10-05 10:20:08',
#  '2021-10-05 10:19:54',
#  '2021-10-05 08:57:43',
#  '2021-10-05 08:34:10',
#  '2021-10-05 04:30:17',
#  '2021-10-05 02:13:55',
#  '2021-10-05 02:07:15',
#  '2021-10-05 01:32:55',
#  '2021-10-04 22:51:06',
#  '2021-10-04 20:49:45',
#  '2021-10-04 20:32:47',
#  '2021-10-04 19:01:29',
#  '2021-10-04 17:15:09',
#  '2021-10-04 17:05:33',
#  '2021-10-04 16:59:05',
#  '2021-10-04 14:32:40',
#  '2021-10-04 13:54:59',
#  '2021-10-04 10:59:28',
#  '2021-10-04 10:38:16',
#  '2021-10-04 09:44:56',
#  '2021-10-04 09:29:12',
#  '2021-10-04 09:24:33',
#  '2021-10-04 09:15:23',
#  '2021-10-04 09:11:56',
#  '2021-10-04 09:11:20',
#  '2021-10-04 01:57:15',
#  '2021-10-03 10:06:47',
#  '2021-10-03 04:40:43',
#  '2021-10-03 03:21:47',
#  '2021-10-03 03:17:53',
#  '2021-10-02 20:54:09',
#  '2021-10-02 15:13:18',
#  '2021-10-02 13:57:18',
#  '2021-10-02 10:06:16',
#  '2021-10-02 01:01:38',
#  '2021-10-01 22:52:25',
#  '2021-10-01 22:51:05',
#  '2021-10-01 22:20:17',
#  '2021-10-01 22:18:12',
#  '2021-10-01 22:04:18',
#  '2021-10-01 21:31:06',
#  '2021-10-01 20:04:48',
#  '2021-10-01 18:38:42',
#  '2021-10-01 17:39:26',
#  '2021-10-01 14:58:01',
#  '2021-10-01 14:48:50',
#  '2021-10-01 14:13:22',
#  '2021-10-01 13:59:46',
#  '2021-10-01 12:50:32',
#  '2021-10-01 12:42:23',
#  '2021-10-01 12:25:46',
#  '2021-10-01 12:13:32',
#  '2021-10-01 12:05:23',
#  '2021-10-01 11:59:31',
#  '2021-10-01 11:43:46',
#  '2021-10-01 11:31:03',
#  '2021-10-01 11:23:30',
#  '2021-10-01 11:18:12',
#  '2021-10-01 11:17:25',
#  '2021-10-01 10:48:59',
#  '2021-10-01 10:46:48',
#  '2021-10-01 10:18:51',
#  '2021-10-01 10:00:10',
#  '2021-10-01 09:59:22',
#  '2021-10-01 06:03:07',
#  '2021-09-30 23:35:29',
#  '2021-09-30 20:03:42',
#  '2021-09-30 18:56:33',
#  '2021-09-30 17:38:54',
#  '2021-09-30 12:19:17',
#  '2021-09-30 11:54:08',
#  '2021-09-30 11:46:57',
#  '2021-09-30 11:02:08',
#  '2021-09-29 15:36:32',
#  '2021-09-29 15:34:11',
#  '2021-09-29 14:16:08',
#  '2021-09-29 14:03:35',
#  '2021-09-29 13:55:25',
#  '2021-09-29 13:52:52',
#  '2021-09-29 13:44:34',
#  '2021-09-29 13:36:58',
#  '2021-09-29 13:33:27',
#  '2021-09-29 13:28:39',
#  '2021-09-29 13:25:04',
#  '2021-09-29 13:19:35',
#  '2021-09-29 12:27:58',
#  '2021-09-29 12:09:34',
#  '2021-09-29 12:07:10',
#  '2021-09-29 11:41:48',
#  '2021-09-29 11:14:37',
#  '2021-09-29 10:41:02',
#  '2021-09-29 10:39:46',
#  '2021-09-29 09:34:38',
#  '2021-09-29 05:19:02',
#  '2021-09-29 05:14:08',
#  '2021-09-29 03:16:31',
#  '2021-09-28 22:46:06',
#  '2021-09-28 21:27:46',
#  '2021-09-28 20:32:38',
#  '2021-09-28 20:31:08',
#  '2021-09-28 16:50:25',
#  '2021-09-28 15:09:50',
#  '2021-09-28 09:56:32',
#  '2021-09-28 08:50:22',
#  '2021-09-28 08:32:14',
#  '2021-09-27 23:02:57',
#  '2021-09-27 22:57:02',
#  '2021-09-27 22:53:17',
#  '2021-09-27 21:32:38',
#  '2021-09-27 08:38:58',
#  '2021-09-26 22:56:40',
#  '2021-09-26 14:11:25',
#  '2021-09-26 08:47:23',
#  '2021-09-25 19:27:47',
#  '2021-09-25 12:06:30',
#  '2021-09-24 15:28:30',
#  '2021-09-24 12:58:13',
#  '2021-09-24 11:29:37',
#  '2021-09-24 10:15:33',
#  '2021-09-24 09:55:35',
#  '2021-09-24 09:49:34',
#  '2021-09-24 09:27:01',
#  '2021-09-24 08:24:12',
#  '2021-09-24 07:23:12',
#  '2021-09-24 03:31:39',
#  '2021-09-24 03:14:40',
#  '2021-09-24 02:04:44',
#  '2021-09-23 23:39:03',
#  '2021-09-23 22:55:31',
#  '2021-09-23 22:10:41',
#  '2021-09-23 20:59:29',
#  '2021-09-23 20:44:56',
#  '2021-09-23 19:02:24',
#  '2021-09-23 18:27:34',
#  '2021-09-23 18:25:00',
#  '2021-09-23 18:17:19',
#  '2021-09-23 17:32:04',
#  '2021-09-23 17:31:28',
#  '2021-09-23 17:30:16',
#  '2021-09-23 17:27:28',
#  '2021-09-23 17:27:27',
#  '2021-09-23 16:56:24',
#  '2021-09-23 15:07:15',
#  '2021-09-23 15:03:26',
#  '2021-09-23 14:24:54',
#  '2021-09-23 12:29:51',
#  '2021-09-23 09:03:06',
#  '2021-09-23 08:47:58',
#  '2021-09-22 20:45:07',
#  '2021-09-22 17:20:00',
#  '2021-09-22 16:07:35',
#  '2021-09-22 02:29:39',
#  '2021-09-21 21:53:02',
#  '2021-09-21 21:27:29',
#  '2021-09-21 20:44:10',
#  '2021-09-21 19:29:20',
#  '2021-09-21 19:22:30',
#  '2021-09-21 14:14:03',
#  '2021-09-21 14:07:43',
#  '2021-09-21 13:37:11',
#  '2021-09-21 12:40:01']

# %%
Date[-1] <= '2021-09-20'
# Out:
# False

# %%
page

# %%
k
