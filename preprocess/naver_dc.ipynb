# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
DC = pd.DataFrame([json.loads(line) for line in open('./DC1125.json', 'r', encoding = 'utf8').readlines()])
# code, date, title, view, recommend 다 같으면 중복으로 처리
# print(DC.info())
DC.drop_duplicates(subset = DC.columns[1:], inplace=True)
DC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13571 entries, 0 to 13576
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   _id        13571 non-null  object
#  1   code       13571 non-null  object
#  2   date       13571 non-null  object
#  3   title      13571 non-null  object
#  4   view       13571 non-null  object
#  5   recommend  13571 non-null  object
# dtypes: object(6)
# memory usage: 742.2+ KB

# %%
DC
# Out:
#                                         _id    code                 date  \
# 0      {'$oid': '619f8ec272ef621a85e798df'}  008770  2021-11-23 15:09:00
# 5      {'$oid': '619f8f4b72ef621a85e798e4'}  008770  2021-11-22 15:00:25
# 6      {'$oid': '619f8f4c72ef621a85e798e5'}  008770  2021-11-20 00:22:54
# 7      {'$oid': '619f8f4c72ef621a85e798e6'}  008770  2021-11-18 12:49:15
# 8      {'$oid': '619f8f4d72ef621a85e798e7'}  008770  2021-11-16 12:58:34
# ...                                     ...     ...                  ...
# 13572  {'$oid': '619f95c072ef621a85e7cde3'}  069410  2021-09-20 01:23:03
# 13573  {'$oid': '619f95c072ef621a85e7cde4'}  069410  2021-09-20 01:19:34
# 13574  {'$oid': '619f95c272ef621a85e7cde5'}  069410  2021-09-14 17:53:32
# 13575  {'$oid': '619f95c272ef621a85e7cde6'}  069410  2021-09-13 14:26:24
# 13576  {'$oid': '619f95c772ef621a85e7cde7'}  069410  2021-08-25 12:28:42
#
#                                     title view recommend
# ...

# %%
NAVER = pd.DataFrame([json.loads(line) for line in open('./naver_1114.json', 'r', encoding = 'utf8').readlines()])
# code, title 다 같으면 중복으로 처리, view 합체
NAVER.drop_duplicates(subset = ['code', 'title'], inplace=True)
NAVER.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78798 entries, 0 to 79014
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   _id     78798 non-null  object
#  1   code    78798 non-null  object
#  2   date    78798 non-null  object
#  3   title   78798 non-null  object
#  4   views   78798 non-null  object
#  5   pos     78798 non-null  object
#  6   neg     78798 non-null  object
# dtypes: object(7)
# memory usage: 4.8+ MB

# %%
NAVER
# Out:
#                                         _id    code              date  \
# 0      {'$oid': '6191bdc5dcf6bc26b37e2c53'}  008770  2021.11.15 10:44
# 1      {'$oid': '6191bdc5dcf6bc26b37e2c54'}  008770  2021.11.15 10:24
# 2      {'$oid': '6191bdc5dcf6bc26b37e2c55'}  008770  2021.11.15 10:16
# 3      {'$oid': '6191bdc5dcf6bc26b37e2c56'}  008770  2021.11.15 10:14
# 4      {'$oid': '6191bdc5dcf6bc26b37e2c57'}  008770  2021.11.15 10:07
# ...                                     ...     ...               ...
# 79010  {'$oid': '6191d000dcf6bc26b37f60f5'}  069410  2021.11.02 15:42
# 79011  {'$oid': '6191d000dcf6bc26b37f60f6'}  069410  2021.11.02 15:23
# 79012  {'$oid': '6191d000dcf6bc26b37f60f7'}  069410  2021.11.02 11:46
# 79013  {'$oid': '6191d000dcf6bc26b37f60f8'}  069410  2021.11.02 11:12
# 79014  {'$oid': '6191d000dcf6bc26b37f60f9'}  069410  2021.11.02 10:15
#
#                           title views pos neg
# 0                   공매많은 종목인가요?     7   0   0
# ...
